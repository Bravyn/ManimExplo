# %% [markdown]
# <a href="https://colab.research.google.com/github/Bravyn/ManimExplo/blob/main/manim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt update
# !sudo apt install libcairo2-dev ffmpeg \
    texlive texlive-latex-extra texlive-fonts-extra \
    texlive-latex-recommended texlive-science \
    tipa libpango1.0-dev
# !pip install manim
# !pip install IPython --upgrade

# %%
from manim import *
# Out:
# Manim Community v0.17.3

# %%
# %%manim -qm -v WARNING SquareToCircle
#
#
# class SquareToCircle(Scene):
#    def construct(self):
#       square = Square()
#       circle = Circle()
#       circle.set_fill(YELLOW, opacity=0.7)
#       self.play(Create(square))
#       self.play(Create(circle))
#       self.play(Transform(circle, square))
#       self.wait()
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm -v WARNING Addition
#
# class Addition(Scene):
#    def construct(self):
#       square = Square()
#       circle = Circle()
#       circle.set_fill(YELLOW, opacity=0.7)
#       self.play(Create(circle))
#       self.play(Transform(circle, square))
#       self.wait()
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# %%manim -qm -v WARNING Smile
#
# class Smile(Scene):
#   def construct(self):
#     circle = Circle()
#     square = Square()
#
#     self.play(Create(circle))
#     self.play(Create(square))
#     circle.set_fill(BLUE, opacity = .9)
#     self.play(Create(circle))
#     square.set_fill(WHITE, opacity = .3)
#     self.play(Transform(circle, square))
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# The manim library has a way of doing things, fundamental to them is the idea of creating animations with code, specifically with the construct method

# %% [markdown]
# Let me learn how to create some text in this awesome library. Remember, to make the code do something, that is, to make it show some video output as we desire, we must append this code %%manim -qm -v WARNING ClassName

# %%
# %%manim -qm -v WARNING ShowText
#
# class ShowText(Scene):
#   def construct(self):
#     text = Text("Hello World", font_size=44)
#     self.add(text)

# %% [markdown]
# So as we have seen, manim uses the Text() class or whatever it is i don't know for  now. After creating the text, we use the self.add() method . I wonder what other arguments we can pass apart from font-size

# %%
# %%manim -qm -v WARNING ShowMore
#
# class ShowMore(Scene):
#   def construct(self):
#     text = Text("Hello Manim")
#     self.add(text)

# %% [markdown]
# As you have probably noticed, each class we create in Manim extends the Scene class

# %% [markdown]
# # Bringing it all together

# %% [markdown]
# Now let's combine some text and some shapes to see what happens.

# %%
# %%manim -qm -v WARNING ShowAll
#
# class ShowAll(Scene):
#   def construct(self):
#     text = Text("Let us combine our knowledge so far...", font_size= 36)
#     text2 = Text("Now to the circle...", font_size= 36)
#     circle = Circle(2);
#     square = Square(4)#4 is the side length of our square
#     self.add(text)
#     self.wait(2)
#     self.remove(text)
#     self.play(Create(square))
#     self.wait(3)
#     self.add(text2)
#     self.wait(3)
#     self.remove(text2)
#     #self.wait(1)
#     self.play(Transform(text2, circle))
#     self.wait(5)
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
